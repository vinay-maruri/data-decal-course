# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://en.wikipedia.org/wiki/NASCAR"
r = requests.get(url)

# %%
content = BeautifulSoup(r.text, "html.parser")

# %%
print(content.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    NASCAR - Wikipedia
#   </title>
#   <script>
# ...

# %%
content.find("", class_ = "shortdescription nomobile noexcerpt noprint searchaux")
# Out:
# <div class="shortdescription nomobile noexcerpt noprint searchaux" style="display:none">American automobile racing sanctioning company</div>
